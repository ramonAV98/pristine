# %%
# %load_ext autoreload
# %autoreload 2
import os
PATH = '/Users/ramonamezquita/PycharmProjects/pristine'
os.chdir(PATH)

# %%
from criteria.criteria_verifier import criteria_verifier
import pandas as pd

# %%
# Tickers collection

tickers = pd.read_csv('companylist.csv')['Symbol'].values.tolist()

# %%
# Date range including only business days

date_range = pd.bdate_range('2021-01-01', 'today')

# %%
# Boolean matrix for single stock

stock = ['TXG']
df_buy_history = pd.DataFrame()
for date in date_range:
    df_buy, _ = criteria_verifier(stock, date)
    df_buy.loc[:, 'Date'] = date
    df_buy_history = df_buy_history.append(df_buy)
df_buy_history.reset_index(inplace=True)
df_buy_history.rename(columns={'index': 'symbol'}, inplace=True)

# %%
df_buy_history
# Out:
#    symbol  setup  cambio de guardia  cola de piso  narrow body  pz  \
# 0     TXG      0                  0             0            1   0
# 1     TXG      0                  0             0            1   0
# 2     TXG      1                  0             0            1   0
# 3     TXG      0                  0             0            1   0
# 4     TXG      0                  0             1            0   0
# 5     TXG      0                  0             0            1   0
# 6     TXG      0                  0             1            0   0
# 7     TXG      0                  0             0            0   0
# 8     TXG      0                  0             1            0   0
# 9     TXG      0                  0             0            0   0
# 10    TXG      0                  0             0            1   0
# 11    TXG      0                  0             0            1   0
# 12    TXG      0                  0             0            0   0
# ...
